# %%
# !pip uninstall paddleocr -y
# !pip uninstall paddlepaddle -y
# Out:
# WARNING: Skipping paddleocr as it is not installed.
# WARNING: Skipping paddlepaddle as it is not installed.

# %%
# !pip install paddlepaddle
# !pip install paddleocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 23.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 30.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 73.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 25.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 104.7 MB/s eta 0:00:00
# ...

# %%
# !pip install paddlepaddle-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip show paddleocr
# Out:
# Name: paddleocr
# Version: 2.7.3
# Summary: Awesome OCR toolkits based on PaddlePaddle (8.6M ultra-lightweight pre-trained model, support training and deployment among server, mobile, embeded and IoT devices)
# Home-page: https://github.com/PaddlePaddle/PaddleOCR
# Author:
# Author-email:
# License: Apache License 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: attrdict, beautifulsoup4, cython, fire, fonttools, imgaug, lmdb, lxml, numpy, opencv-contrib-python, opencv-python, openpyxl, pdf2docx, Pillow, premailer, pyclipper, python-docx, pyyaml, rapidfuzz, scikit-image, shapely, tqdm, visualdl
# Required-by:

# %%
# !wget https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/det_r50_vd_db_v2.0_train.tar
# Out:
# --2024-05-10 13:48:48--  https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/det_r50_vd_db_v2.0_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 436234240 (416M) [application/x-tar]
# Saving to: ‘det_r50_vd_db_v2.0_train.tar’
#
# det_r50_vd_db_v2.0_ 100%[===================>] 416.03M  9.45MB/s    in 57s
#
# 2024-05-10 13:49:47 (7.33 MB/s) - ‘det_r50_vd_db_v2.0_train.tar’ saved [436234240/436234240]

# %%
# !git clone https://github.com/nhannguyen1003/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 69290, done.
# remote: Counting objects: 100% (30699/30699), done.
# remote: Compressing objects: 100% (21493/21493), done.
# remote: Total 69290 (delta 9234), reused 30502 (delta 9189), pack-reused 38591
# Receiving objects: 100% (69290/69290), 1.38 GiB | 30.63 MiB/s, done.
# Resolving deltas: 100% (36508/36508), done.
# Updating files: 100% (31722/31722), done.

# %%
# !tar -xvf /content/det_r50_vd_db_v2.0_train.tar -C /content/PaddleOCR
# Out:
# det_r50_vd_db_v2.0_train/
# det_r50_vd_db_v2.0_train/best_accuracy.pdopt
# det_r50_vd_db_v2.0_train/.DS_Store
# det_r50_vd_db_v2.0_train/train.log
# det_r50_vd_db_v2.0_train/best_accuracy.pdparams
# det_r50_vd_db_v2.0_train/best_accuracy.states

# %%
import os
os.chdir('/content/PaddleOCR')

# %%
# !python /content/PaddleOCR/tools/train.py -c /content/PaddleOCR/configs/det/det_r50_db++_icdar15.yml

# %%
# !python tools/export_model.py -c /content/PaddleOCR/configs/det/det_r50_vd_db.yml -o Global.save_inference_dir=/content/PaddleOCR/inference/db

# %%
# !paddleocr  --image_dir="/content/1-56-2013.doc-image-1.png" \
                   --use_gpu=='True' \
                   --rec_algorithm="SVTR_LCNet" \
                   --rec_model_dir="/content/drive/MyDrive/Colab Notebooks/SVTR_LCNet" \
                   --lang="vi" \
                   --rec_char_dict_path="/content/drive/MyDrive/Colab Notebooks/vn_dict.txt" \
                   --e2e_char_dict_path="/content/drive/MyDrive/Colab Notebooks/vn_dict.txt"

# %%
# !python tools/infer/predict_det.py  --det_algorithm="DB" \
                                   --use_gpu=True \
                                   --det_model_dir="/content/PaddleOCR/inference/db"  \
                                   --image_dir="/content/1-56-2013.doc-image-1.png"
# Out:
# [2024/05/10 01:02:58] ppocr INFO: 1-56-2013.doc-image-1.png	[[[1218.0, 1610.0], [1274.0, 1610.0], [1274.0, 1649.0], [1218.0, 1649.0]]]
#
# [2024/05/10 01:02:58] ppocr INFO: 0 The predict time of /content/1-56-2013.doc-image-1.png: 0.7109987735748291
# [2024/05/10 01:02:58] ppocr INFO: The visualized image saved in ./inference_results/det_res_1-56-2013.doc-image-1.png

# %%
# !python content/PaddleOCR/tools/infer/predict_system.py \
    --use_gpu=True \
    --det_algorithm="DB"  \
    --det_model_dir="./inference/db"  \
    --rec_algorithm="SVTR_LCNet" \
    --rec_model_dir="./inference/SRN"  \
    --rec_image_shape="1, 64, 256"  \
    --rec_char_type="ch"  \
    --rec_char_dict_path="./ppocr/utils/dict/vi_vietnam.txt" \
    --drop_score=0.5  \
    --vis_font_path="./font-times-new-roman.ttf" \
    --image_dir="your_test_image_path"

# %%
import paddle
import paddleocr

print("PaddlePaddle version:", paddle.__version__)
print("PaddleOCR version:", paddleocr.__version__)
# Out:
# PaddlePaddle version: 2.6.1
# PaddleOCR version: 2.7.3
