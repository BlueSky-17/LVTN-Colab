# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !python3 -m pip install paddlepaddle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/nhannguyen1003/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 69290, done.
# remote: Counting objects: 100% (30699/30699), done.
# remote: Compressing objects: 100% (21493/21493), done.
# remote: Total 69290 (delta 9234), reused 30500 (delta 9189), pack-reused 38591
# Receiving objects: 100% (69290/69290), 1.38 GiB | 29.60 MiB/s, done.
# Resolving deltas: 100% (36508/36508), done.
# Updating files: 100% (31722/31722), done.

# %%
# !pip3 install -r /content/PaddleOCR/requirements.txt

# %%
# !pip install "paddleocr>=2.0.6"

# %%
# !pip install --upgrade paddlepaddle-gpu

# %%
# !wget -c https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/rec_r50_vd_srn_train.tar

# !mv "/content/drive/My Drive/path_to_your_file/your_file_name" "/content/PaddleOCR/"

# %%
# !wget -c https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/det_r50_vd_db_v2.0_train.tar
# Out:
# --2024-05-10 15:43:28--  https://paddleocr.bj.bcebos.com/dygraph_v2.0/en/det_r50_vd_db_v2.0_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 436234240 (416M) [application/x-tar]
# Saving to: ‘det_r50_vd_db_v2.0_train.tar’
#
# det_r50_vd_db_v2.0_ 100%[===================>] 416.03M  10.3MB/s    in 61s
#
# 2024-05-10 15:44:31 (6.87 MB/s) - ‘det_r50_vd_db_v2.0_train.tar’ saved [436234240/436234240]

# %%
# !tar -xvf /content/det_r50_vd_db_v2.0_train.tar -C /content/PaddleOCR
# Out:
# det_r50_vd_db_v2.0_train/
# det_r50_vd_db_v2.0_train/best_accuracy.pdopt
# det_r50_vd_db_v2.0_train/.DS_Store
# det_r50_vd_db_v2.0_train/train.log
# det_r50_vd_db_v2.0_train/best_accuracy.pdparams
# det_r50_vd_db_v2.0_train/best_accuracy.states

# %%
# !tar -xvf /content/rec_r50_vd_srn_train.tar -C /content/PaddleOCR
# Out:
# rec_r50_vd_srn_train/
# rec_r50_vd_srn_train/best_accuracy.states
# rec_r50_vd_srn_train/best_accuracy.pdparams
# rec_r50_vd_srn_train/best_accuracy.pdopt

# %%
import os
os.chdir('/content/PaddleOCR')

# %%
# !python3 /content/PaddleOCR/tools/train.py -c /content/PaddleOCR/configs/det/det_r50_vd_db.yml
# Out:
# Streaming output truncated to the last 5000 lines.
# json.decoder.JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# [2024/05/10 15:57:24] ppocr ERROR: When parsing line im0277_14.jpg	TẤN
# , error happened with msg: Traceback (most recent call last):
#   File "/content/PaddleOCR/ppocr/data/simple_dataset.py", line 162, in __getitem__
#     outs = transform(data, self.ops)
#   File "/content/PaddleOCR/ppocr/data/imaug/__init__.py", line 71, in transform
#     data = op(data)
#   File "/content/PaddleOCR/ppocr/data/imaug/label_ops.py", line 52, in __call__
#     label = json.loads(label)
#   File "/usr/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.10/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.10/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# ...

# %%
# !python3 /content/PaddleOCR/tools/train.py -c /content/PaddleOCR/configs/rec/rec_r50_fpn_srn.yml

# %%
# !python tools/export_model.py -c ./configs/rec/rec_r50_fpn_srn.yml \
                             -o Global.pretrained_model=./output/SRN/latest \
                                Global.save_inference_dir=./inference/SRN
# Out:
# W0510 15:25:15.909518 12264 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 12.2, Runtime API Version: 11.8
# W0510 15:25:15.910708 12264 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2024/05/10 15:25:16] ppocr INFO: load pretrain successful from ./output/SRN/latest
# I0510 15:25:21.939200 12264 program_interpreter.cc:212] New Executor is Running.
# [2024/05/10 15:25:22] ppocr INFO: inference model is saved to ./inference/SRN/inference

# %%
# !python tools/infer/predict_rec.py  --image_dir="./train/vietnamese/train/img_crop/im0001_2.jpg" \
                                   --use_gpu=False \
                                   --rec_algorithm="SRN" \
                                   --rec_image_shape="1, 64, 256"  \
                                   --rec_model_dir="./inference/SRN"  \
                                   --rec_char_dict_path="./ppocr/utils/dict/vi_dict.txt"
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleOCR/tools/infer/predict_rec.py", line 743, in <module>
#     main(utility.parse_args())
#   File "/content/PaddleOCR/tools/infer/predict_rec.py", line 704, in main
#     text_recognizer = TextRecognizer(args)
#   File "/content/PaddleOCR/tools/infer/predict_rec.py", line 147, in __init__
#     ) = utility.create_predictor(args, "rec", logger)
#   File "/content/PaddleOCR/tools/infer/utility.py", line 296, in create_predictor
#     predictor = inference.create_predictor(config)
# ValueError: (InvalidArgument) The Input Variable(X) of (reshape2) Operator used to determine kernel data type is empty or not phi::DenseTensor or SelectedRows or LoDTensorArray.
#   [Hint: Expected data_type != dafault_data_type, but received data_type:-1 == dafault_data_type:-1.] (at /paddle/paddle/fluid/framework/operator.cc:2932)
#   [operator < reshape2 > error]

# %%
# !python ./tools/infer/predict_system.py \
    --use_gpu=True \
        --det_algorithm="SAST"  \
        --det_model_dir="./inference/SAST"  \
        --rec_algorithm="SVTR_LCNet" \
        --rec_model_dir="./inference/rec_ppocr_v4"  \
        --rec_char_dict_path="./ppocr/utils/dict/vi_dict.txt" \
        --drop_score=0.5  \
        --vis_font_path="./font-times-new-roman.ttf" \
        --image_dir="/content/PaddleOCR/train/vietnamese/test_image/1-1-56-2013.doc-image-1.png"
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 295, in <module>
#     main(args)
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 157, in main
#     text_sys = TextSystem(args)
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 51, in __init__
#     self.text_detector = predict_det.TextDetector(args)
#   File "/content/PaddleOCR/tools/infer/predict_det.py", line 139, in __init__
#     ) = utility.create_predictor(args, "det", logger)
#   File "/content/PaddleOCR/tools/infer/utility.py", line 296, in create_predictor
#     predictor = inference.create_predictor(config)
# ValueError: (InvalidArgument) Deserialize to tensor failed, maybe the loaded file is not a paddle model(expected file format: 0, but 3153442269 found).
#   [Hint: Expected version == 0U, but received version:3153442269 != 0U:0.] (at /paddle/paddle/fluid/framework/lod_tensor.cc:301)
#   [operator < load_combine > error]

# %%
# !paddleocr --image_dir /content/01_84_2019.doc-image-1.png --use_angle_cls true --lang en --use_gpu true
# Out:
# [2024/05/02 15:43:30] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir='/content/01_84_2019.doc-image-1.png', page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_te
# ...

# %%
# !paddleocr --image_dir /content/1-1-56-2013.doc-image-1.png --lang en --type=structure --table=false --ocr=false
# Out:
# [2024/05/02 15:56:35] ppocr DEBUG: Namespace(help='==SUPPRESS==', use_gpu=True, use_xpu=False, use_npu=False, ir_optim=True, use_tensorrt=False, min_subgraph_size=15, precision='fp32', gpu_mem=500, gpu_id=0, image_dir='/content/1-1-56-2013.doc-image-1.png', page_num=0, det_algorithm='DB', det_model_dir='/root/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_limit_side_len=960, det_limit_type='max', det_box_type='quad', det_db_thresh=0.3, det_db_box_thresh=0.6, det_db_unclip_ratio=1.5, max_batch_size=10, use_dilation=False, det_db_score_mode='fast', det_east_score_thresh=0.8, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_sast_score_thresh=0.5, det_sast_nms_thresh=0.2, det_pse_thresh=0, det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, scales=[8, 16, 32], alpha=1.0, beta=1.0, fourier_degree=5, rec_algorithm='SVTR_LCNet', rec_model_dir='/root/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_batch_num=6, max_t
# ...

# %%
# !paddleocr -v
# Out:
# usage: paddleocr [-h] [--use_gpu USE_GPU] [--use_xpu USE_XPU] [--use_npu USE_NPU]
#                  [--ir_optim IR_OPTIM] [--use_tensorrt USE_TENSORRT]
#                  [--min_subgraph_size MIN_SUBGRAPH_SIZE] [--precision PRECISION]
#                  [--gpu_mem GPU_MEM] [--gpu_id GPU_ID] [--image_dir IMAGE_DIR]
#                  [--page_num PAGE_NUM] [--det_algorithm DET_ALGORITHM]
#                  [--det_model_dir DET_MODEL_DIR] [--det_limit_side_len DET_LIMIT_SIDE_LEN]
#                  [--det_limit_type DET_LIMIT_TYPE] [--det_box_type DET_BOX_TYPE]
#                  [--det_db_thresh DET_DB_THRESH] [--det_db_box_thresh DET_DB_BOX_THRESH]
#                  [--det_db_unclip_ratio DET_DB_UNCLIP_RATIO] [--max_batch_size MAX_BATCH_SIZE]
#                  [--use_dilation USE_DILATION] [--det_db_score_mode DET_DB_SCORE_MODE]
#                  [--det_east_score_thresh DET_EAST_SCORE_THRESH]
#                  [--det_east_cover_thresh DET_EAST_COVER_THRESH]
# ...
