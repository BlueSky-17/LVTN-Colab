# %%
# !python3 --version
# Out:
# Python 3.10.12

# %%
# !python3 -m pip install paddlepaddle
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 MB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/nhannguyen1003/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 69290, done.
# remote: Counting objects: 100% (30699/30699), done.
# remote: Compressing objects: 100% (21494/21494), done.
# remote: Total 69290 (delta 9233), reused 30494 (delta 9188), pack-reused 38591
# Receiving objects: 100% (69290/69290), 1.38 GiB | 23.22 MiB/s, done.
# Resolving deltas: 100% (36614/36614), done.
# Updating files: 100% (31722/31722), done.

# %%
# !pip3 install -r /content/PaddleOCR/requirements.txt

# %%
# !pip install "paddleocr>=2.0.6"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 42.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.6/239.6 kB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 72.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 398.1/398.1 kB 42.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.5/331.5 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 48.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.2 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade paddlepaddle-gpu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.5 MB/s eta 0:00:00
# ...

# %%
# !wget -P /content/PaddleOCR/ https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_train.tar

# !mv "/content/drive/My Drive/path_to_your_file/your_file_name" "/content/PaddleOCR/"
# Out:
# --2024-04-29 17:13:35--  https://paddleocr.bj.bcebos.com/PP-OCRv4/english/en_PP-OCRv4_rec_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1203:0:ff:b0bb:4f27
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190740480 (182M) [application/x-tar]
# Saving to: ‘/content/PaddleOCR/en_PP-OCRv4_rec_train.tar’
#
# en_PP-OCRv4_rec_tra 100%[===================>] 181.90M  10.8MB/s    in 30s
#
# 2024-04-29 17:14:07 (6.01 MB/s) - ‘/content/PaddleOCR/en_PP-OCRv4_rec_train.tar’ saved [190740480/190740480]

# %%
# !ls /content/PaddleOCR/en_PP-OCRv4_rec_train.tar
# Out:
# /content/PaddleOCR/en_PP-OCRv4_rec_train.tar

# %%
# !tar -xvf /content/PaddleOCR/en_PP-OCRv4_rec_train.tar -C /content/PaddleOCR
# Out:
# en_PP-OCRv4_rec_train/
# en_PP-OCRv4_rec_train/best_accuracy.pdopt
# en_PP-OCRv4_rec_train/best_accuracy.states
# en_PP-OCRv4_rec_train/best_accuracy.pdparams

# %%
import os
os.chdir('/content/PaddleOCR')

# %%
# !python /content/PaddleOCR/tools/train.py -c /content/PaddleOCR/configs/rec/PP-OCRv4/en_PP-OCRv4_rec.yml  -o Global.checkpoints=./output/PPOCR_v4/latest
# Out:
# Streaming output truncated to the last 5000 lines.
# [2024/04/29 19:53:26] ppocr INFO: epoch: [74/200], global_step: 17860, lr: 0.000370, acc: 0.828125, norm_edit_dis: 0.963691, CTCLoss: 0.923298, NRTRLoss: 0.937334, loss: 1.855208, avg_reader_cost: 0.37511 s, avg_batch_cost: 0.57626 s, avg_samples: 32.0, ips: 55.53070 samples/s, eta: 6:02:16, max_mem_reserved: 13197 MB, max_mem_allocated: 11980 MB
# [2024/04/29 19:53:30] ppocr INFO: epoch: [74/200], global_step: 17870, lr: 0.000370, acc: 0.843750, norm_edit_dis: 0.965123, CTCLoss: 0.817853, NRTRLoss: 0.931201, loss: 1.750760, avg_reader_cost: 0.00025 s, avg_batch_cost: 0.45071 s, avg_samples: 67.2, ips: 149.09955 samples/s, eta: 6:02:11, max_mem_reserved: 13197 MB, max_mem_allocated: 11980 MB
# ...

# %%
# !python tools/export_model.py -c ./configs/rec/PP-OCRv4/en_PP-OCRv4_rec.yml \
                             -o Global.pretrained_model=./output/rec_ppocr_v4/latest \
                                Global.save_inference_dir=./inference/rec_ppocr_v4
# Out:
# W0430 02:07:48.264216 148696 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 12.2, Runtime API Version: 11.8
# W0430 02:07:48.265332 148696 gpu_resources.cc:164] device: 0, cuDNN Version: 8.9.
# [2024/04/30 02:07:48] ppocr INFO: load pretrain successful from ./output/rec_ppocr_v4/latest
# I0430 02:07:55.801646 148696 program_interpreter.cc:212] New Executor is Running.
# [2024/04/30 02:07:55] ppocr INFO: inference model is saved to ./inference/rec_ppocr_v4/inference

# %%
# !python tools/infer/predict_rec.py  --image_dir="./train/vietnamese/train/img_crop/im0001_2.jpg" \
                                   --use_gpu=True \
                                   --rec_algorithm="SVTR_LCNet" \
                                   --rec_model_dir="./inference/rec_ppocr_v4"  \
                                   --rec_char_dict_path="./ppocr/utils/dict/vi_dict.txt"
# Out:
# [2024/04/30 03:25:35] ppocr INFO: In PP-OCRv3, rec_image_shape parameter defaults to '3, 48, 320', if you are using recognition model with PP-OCRv2 or an older version, please set --rec_image_shape='3,32,320
# [2024/04/30 03:25:36] ppocr INFO: Predicts of ./train/vietnamese/train/img_crop/im0001_2.jpg:('TỐTGẾ', 0.71343994140625)

# %%
# !python ./tools/infer/predict_system.py \
    --use_gpu=True \
        --det_algorithm="SAST"  \
        --det_model_dir="./inference/SAST"  \
        --rec_algorithm="SVTR_LCNet" \
        --rec_model_dir="./inference/rec_ppocr_v4"  \
        --rec_char_dict_path="./ppocr/utils/dict/vi_dict.txt" \
        --drop_score=0.5  \
        --vis_font_path="./font-times-new-roman.ttf" \
        --image_dir="/content/PaddleOCR/train/vietnamese/test_image/1-1-56-2013.doc-image-1.png"
# Out:
# Traceback (most recent call last):
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 295, in <module>
#     main(args)
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 157, in main
#     text_sys = TextSystem(args)
#   File "/content/PaddleOCR/./tools/infer/predict_system.py", line 51, in __init__
#     self.text_detector = predict_det.TextDetector(args)
#   File "/content/PaddleOCR/tools/infer/predict_det.py", line 139, in __init__
#     ) = utility.create_predictor(args, "det", logger)
#   File "/content/PaddleOCR/tools/infer/utility.py", line 296, in create_predictor
#     predictor = inference.create_predictor(config)
# ValueError: (InvalidArgument) Deserialize to tensor failed, maybe the loaded file is not a paddle model(expected file format: 0, but 3153442269 found).
#   [Hint: Expected version == 0U, but received version:3153442269 != 0U:0.] (at /paddle/paddle/fluid/framework/lod_tensor.cc:301)
#   [operator < load_combine > error]
